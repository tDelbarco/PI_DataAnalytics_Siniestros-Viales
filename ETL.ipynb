# %%
import pandas as pd
import  numpy as np

# %% [markdown]
# <hr>

# %% [markdown]
# # Poblacion

# %%
poblacion = pd.ExcelFile(r"Datasets_adicionales/PDE.xlsx")

# %%
poblacion.sheet_names
# Out:
# ['PDE',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  'Ficha Técnica']

# %%
a2016 = poblacion.parse("2016",header=1)
a2017 = poblacion.parse("2017",header=1)
a2018 = poblacion.parse("2018",header=1)
a2019 = poblacion.parse("2019",header=1)
a2020 = poblacion.parse("2020",header=1)
a2021 = poblacion.parse("2021",header=1)

# %%
a2016 = a2016["Población"][1]
a2017 = a2017["Población"][1]
a2018 = a2018["Población"][1]
a2019 = a2019["Población"][1]
a2020 = a2020["Población"][1]
a2021 = a2021["Población"][1]

# %%
a2016
# Out:
# 3059122

# %%
pob_BA = pd.DataFrame([a2016,a2017,a2018,a2019,a2020,a2021],index=["2016","2017","2018","2019","2020","2021"],columns=["poblacion"])

# %%
pob_BA
# Out:
#       poblacion
# 2016    3059122
# 2017    3063728
# 2018    3068043
# 2019    3072029
# 2020    3075646
# 2021    3078836

# %%
pob_BA = pob_BA.reset_index()

# %%
pob_BA = pob_BA.rename(columns={'index': 'anio'})

# %%
pob_BA
# Out:
#    anio  poblacion
# 0  2016    3059122
# 1  2017    3063728
# 2  2018    3068043
# 3  2019    3072029
# 4  2020    3075646
# 5  2021    3078836

# %%
pob_BA.to_csv(r"Datasets_adicionales/poblacion_año.csv")

# %% [markdown]
# <hr>

# %%
homicidios_hechos = pd.read_excel(r"Datasets/homicidios.xlsx",sheet_name="HECHOS")

# %%
homicidios_hechos['SEMESTRE'] =homicidios_hechos['MM'].apply(lambda x: 1 if x in [1, 2, 3, 4, 5, 6] else 2)

# %%
homicidios_hechos
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# ..         ...         ...        ...   ...  ..  ..       ...  ..
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...
# ...

# %%
homicidios_hechos["AAAA"].dtype
# Out:
# dtype('int64')

# %%
homicidios_hechos = homicidios_hechos.groupby(['AAAA', 'SEMESTRE'])['N_VICTIMAS'].sum().reset_index()

# %%
homicidios_hechos
# Out:
#     AAAA  SEMESTRE  N_VICTIMAS
# 0   2016         1          65
# 1   2016         2          81
# 2   2017         1          69
# 3   2017         2          71
# 4   2018         1          70
# 5   2018         2          79
# 6   2019         1          57
# 7   2019         2          47
# 8   2020         1          31
# 9   2020         2          50
# 10  2021         1          55
# 11  2021         2          42

# %%
pob_BA["anio"] = pob_BA["anio"].astype(int)

# %%
pob_BA
# Out:
#    anio  poblacion
# 0  2016    3059122
# 1  2017    3063728
# 2  2018    3068043
# 3  2019    3072029
# 4  2020    3075646
# 5  2021    3078836

# %%
df_kpi = homicidios_hechos.merge(pob_BA,left_on="AAAA",right_on="anio")

# %%
df_kpi
# Out:
#     AAAA  SEMESTRE  N_VICTIMAS  anio  poblacion
# 0   2016         1          65  2016    3059122
# 1   2016         2          81  2016    3059122
# 2   2017         1          69  2017    3063728
# 3   2017         2          71  2017    3063728
# 4   2018         1          70  2018    3068043
# 5   2018         2          79  2018    3068043
# 6   2019         1          57  2019    3072029
# 7   2019         2          47  2019    3072029
# 8   2020         1          31  2020    3075646
# 9   2020         2          50  2020    3075646
# 10  2021         1          55  2021    3078836
# 11  2021         2          42  2021    3078836

# %%
df_kpi['tasa'] = (df_kpi['N_VICTIMAS'] / df_kpi['poblacion']) * 100000

# %%
df_kpi
# Out:
#     AAAA  SEMESTRE  N_VICTIMAS  anio  poblacion      tasa
# 0   2016         1          65  2016    3059122  2.124793
# 1   2016         2          81  2016    3059122  2.647819
# 2   2017         1          69  2017    3063728  2.252158
# 3   2017         2          71  2017    3063728  2.317438
# 4   2018         1          70  2018    3068043  2.281585
# 5   2018         2          79  2018    3068043  2.574931
# 6   2019         1          57  2019    3072029  1.855451
# 7   2019         2          47  2019    3072029  1.529933
# 8   2020         1          31  2020    3075646  1.007918
# 9   2020         2          50  2020    3075646  1.625675
# 10  2021         1          55  2021    3078836  1.786389
# 11  2021         2          42  2021    3078836  1.364152

# %%
df_kpi['tasa_anterior'] = df_kpi['tasa'].shift(periods=1, fill_value=0)

# %%
df_kpi
# Out:
#     AAAA  SEMESTRE  N_VICTIMAS  anio  poblacion      tasa  tasa_anterior
# 0   2016         1          65  2016    3059122  2.124793       0.000000
# 1   2016         2          81  2016    3059122  2.647819       2.124793
# 2   2017         1          69  2017    3063728  2.252158       2.647819
# 3   2017         2          71  2017    3063728  2.317438       2.252158
# 4   2018         1          70  2018    3068043  2.281585       2.317438
# 5   2018         2          79  2018    3068043  2.574931       2.281585
# 6   2019         1          57  2019    3072029  1.855451       2.574931
# 7   2019         2          47  2019    3072029  1.529933       1.855451
# 8   2020         1          31  2020    3075646  1.007918       1.529933
# 9   2020         2          50  2020    3075646  1.625675       1.007918
# 10  2021         1          55  2021    3078836  1.786389       1.625675
# 11  2021         2          42  2021    3078836  1.364152       1.786389

# %%
df_kpi['variacion_tasa'] = (df_kpi['tasa'] - df_kpi['tasa_anterior']) / df_kpi['tasa_anterior'] * 100

# %%
df_kpi
# Out:
#     AAAA  SEMESTRE  N_VICTIMAS  anio  poblacion      tasa  tasa_anterior  \
# 0   2016         1          65  2016    3059122  2.124793       0.000000
# 1   2016         2          81  2016    3059122  2.647819       2.124793
# 2   2017         1          69  2017    3063728  2.252158       2.647819
# 3   2017         2          71  2017    3063728  2.317438       2.252158
# 4   2018         1          70  2018    3068043  2.281585       2.317438
# 5   2018         2          79  2018    3068043  2.574931       2.281585
# 6   2019         1          57  2019    3072029  1.855451       2.574931
# 7   2019         2          47  2019    3072029  1.529933       1.855451
# 8   2020         1          31  2020    3075646  1.007918       1.529933
# 9   2020         2          50  2020    3075646  1.625675       1.007918
# 10  2021         1          55  2021    3078836  1.786389       1.625675
# 11  2021         2          42  2021    3078836  1.364152       1.786389
#
# ...

# %%
df_kpi['variacion_tasa'] = df_kpi['variacion_tasa'].replace([np.inf, -np.inf], 0)

# %%
df_kpi = df_kpi.round({'variacion_tasa': 2})

# %%
df_kpi = df_kpi.tail(2)

# %%
df_kpi
# Out:
#     AAAA  SEMESTRE  N_VICTIMAS  anio  poblacion      tasa  tasa_anterior  \
# 10  2021         1          55  2021    3078836  1.786389       1.625675
# 11  2021         2          42  2021    3078836  1.364152       1.786389
#
#     variacion_tasa
# 10            9.89
# 11          -23.64

# %%
df_kpi.to_csv(r"Datasets_adicionales/tasa_hc_semestre.csv",sep=";")

# %% [markdown]
# <hr>

# %%
homicidios_hechos = pd.read_excel(r"Datasets/homicidios.xlsx",sheet_name="HECHOS")

# %%
homicidios_hechos = homicidios_hechos[homicidios_hechos["VICTIMA"] == "MOTO"]

# %%
kpi_motos = homicidios_hechos.groupby("AAAA")["N_VICTIMAS"].sum().reset_index()

# %%
kpi_motos
# Out:
#    AAAA  N_VICTIMAS
# 0  2016          65
# 1  2017          56
# 2  2018          57
# 3  2019          50
# 4  2020          28
# 5  2021          46

# %%
kpi_motos["N_VICTIMAS_ANTERIOR"] = kpi_motos["N_VICTIMAS"].shift(periods=1, fill_value=0)

# %%
kpi_motos["variacion_victimas_moto"] = (kpi_motos["N_VICTIMAS"] - kpi_motos["N_VICTIMAS_ANTERIOR"]) / kpi_motos["N_VICTIMAS_ANTERIOR"] * 100

# %%
kpi_motos
# Out:
#    AAAA  N_VICTIMAS  N_VICTIMAS_ANTERIOR  variacion_victimas_moto
# 0  2016          65                    0                      inf
# 1  2017          56                   65               -13.846154
# 2  2018          57                   56                 1.785714
# 3  2019          50                   57               -12.280702
# 4  2020          28                   50               -44.000000
# 5  2021          46                   28                64.285714

# %%
kpi_motos["variacion_victimas_moto"] = kpi_motos["variacion_victimas_moto"].replace([np.inf, -np.inf], 0)

# %%
kpi_motos = kpi_motos.round({"variacion_victimas_moto": 2})

# %%
kpi_motos = kpi_motos.tail(2)

# %%
kpi_motos
# Out:
#    AAAA  N_VICTIMAS  N_VICTIMAS_ANTERIOR  variacion_victimas_moto
# 4  2020          28                   50                   -44.00
# 5  2021          46                   28                    64.29

# %%
kpi_motos.to_csv(r"Datasets_adicionales/Tasa_hc_moto.csv", sep=";")
